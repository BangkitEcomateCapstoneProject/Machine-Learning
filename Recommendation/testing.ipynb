# %%
from Recommendation import ArticleRecommendation
model = ArticleRecommendation()
result = model.recommendation('C:/Users/Reyhan Dwi/Documents/Reyhan/Bangkit Academy/Recommendation System/Recommendation/englishArticle.csv','how to recycle plastics')
result
# Out:
#      Kode                                              title  \
# 88     89  Recycling Quandary: What To Do About Labels on...
# 80     81  Demystifying Chemical Recycling: An Emerging S...
# 101   102           Recycling Mystery: Black-Colored Plastic
# 3       4               How Many Times Can That Be Recycled?
# 90     91  Recycling Plastic Clamshells and Bottles, the ...
#
#                                            raw_content  \
# 88   Recycling should be simple. But it isn’t. We h...
# 80   The escalating plastic pollution crisis and in...
# 101  Black-colored plastic gets its color from carb...
# 3    I used to think that plastic water bottles cou...
# 90   You’ve probably seen the #1 plastic resin code...
#
#                                          clean_content  date_created  \
# 88   Recycling should be simple. But it isn’t. We h...  Jun 19, 2023
# 80   The escalating plastic pollution crisis and in...   Nov 8, 2023
# ...
